# %% [markdown]
# If you want to start experimenting with continuous-time temporal graph models, you’ll find that many of them are already available on GitHub. In fact, the ecosystem for continuous-time methods is currently stronger than for discrete-time ones: public libraries usually provide better benchmark datasets, training routines, and evaluation settings. This means you can get up and running more quickly, and it’s easier to compare your results with existing work.

# %% [markdown]
# # Reproduce results on TGB
#
# TGB is a collection of challenging and diverse benchmark datasets for realistic, reproducible, and robust evaluation for machine learning on temporal graphs. TGB includes both dynamic link and node property prediction tasks and an automated pipeline from dataset downloading, dataloading, evaluation and submission to the TGB leaderboard.
#
# **Reproducing results on TGB** is very easy and can be achieved using this repository https://github.com/fpour/TGB_Baselines
#
# # Test your own model on TGB
#
# Example adapted from https://github.com/manuel-dileo/lp-heuristics
#
# Let's test a preferential attachment heuristic on a TGB dataset.

# %%
# !pip install --upgrade --force-reinstall py-tgb
# Out:
# Collecting py-tgb
#   Downloading py_tgb-2.1.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting clint<0.6.0,>=0.5.1 (from py-tgb)
#   Downloading clint-0.5.1.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numpy<3.0.0,>=2.0.2 (from py-tgb)
#   Downloading numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 8.8 MB/s eta 0:00:00
# Collecting pandas>=2.2.3 (from py-tgb)
#   Downloading pandas-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 14.3 MB/s eta 0:00:00
# Collecting requests<3.0.0,>=2.28.2 (from py-tgb)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting scikit-learn<2.0.0,>=1.2.2 (from py-tgb)
#   Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting torch-geometric<3.0.0,>=2.3.0 (from py-tgb)
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.7 MB/s eta 0:00:00
# Collecting tqdm<5.0.0,>=4.65.0 (from py-tgb)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 7.2 MB/s eta 0:00:00
# Collecting args (from clint<0.6.0,>=0.5.1->py-tgb)
#   Downloading args-0.1.0.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-dateutil>=2.8.2 (from pandas>=2.2.3->py-tgb)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=2.2.3->py-tgb)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.2.3->py-tgb)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.28.2->py-tgb)
#   Downloading charset_normalizer-3.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.28.2->py-tgb)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.28.2->py-tgb)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.28.2->py-tgb)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting scipy>=1.8.0 (from scikit-learn<2.0.0,>=1.2.2->py-tgb)
#   Downloading scipy-1.16.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 7.9 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn<2.0.0,>=1.2.2->py-tgb)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2.0.0,>=1.2.2->py-tgb)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting aiohttp (from torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading aiohttp-3.12.15-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting fsspec (from torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting jinja2 (from torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting psutil>=5.8.0 (from torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyparsing (from torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>=2.2.3->py-tgb)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp->torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading multidict-6.6.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 6.2 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0 (from jinja2->torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting typing-extensions>=4.2 (from aiosignal>=1.4.0->aiohttp->torch-geometric<3.0.0,>=2.3.0->py-tgb)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading py_tgb-2.1.0-py3-none-any.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 15.2 MB/s eta 0:00:00
# Downloading numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 129.3 MB/s eta 0:00:00
# Downloading pandas-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 185.5 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 11.4 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 167.4 MB/s eta 0:00:00
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 91.4 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 11.1 MB/s eta 0:00:00
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 26.5 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 10.8 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 8.0 MB/s eta 0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 47.1 MB/s eta 0:00:00
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 42.1 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 15.2 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 57.7 MB/s eta 0:00:00
# Downloading scipy-1.16.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 77.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 46.4 MB/s eta 0:00:00
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 16.8 MB/s eta 0:00:00
# Downloading aiohttp-3.12.15-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 103.9 MB/s eta 0:00:00
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 33.6 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 18.9 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 19.4 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 8.3 MB/s eta 0:00:00
# Downloading frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.3/235.3 kB 17.7 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading multidict-6.6.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.7/246.7 kB 37.3 MB/s eta 0:00:00
# Downloading propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.5/213.5 kB 21.1 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (348 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.0/349.0 kB 35.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.3 MB/s eta 0:00:00
# Building wheels for collected packages: clint, args
#   Building wheel for clint (setup.py) ... done
#   Created wheel for clint: filename=clint-0.5.1-py3-none-any.whl size=34457 sha256=fbf2aca48cabfdec9a84ab88c6a6a4bb9462d936a9220e1ce9183592ddd9ec2f
#   Stored in directory: /root/.cache/pip/wheels/a0/8d/f3/91dd49f9a8c6a57be7715f6d11347c49971dd292a53397ed79
#   Building wheel for args (setup.py) ... done
#   Created wheel for args: filename=args-0.1.0-py3-none-any.whl size=3319 sha256=c6305857f794f8db505dea21664c61e74364b2903c6fb75438c8e13f93261e19
#   Stored in directory: /root/.cache/pip/wheels/15/a2/87/2541eb895fd18fd20cc7dd18b14d3b61bd9084cf4322abd15e
# Successfully built clint args
# Installing collected packages: pytz, args, urllib3, tzdata, typing-extensions, tqdm, threadpoolctl, six, pyparsing, psutil, propcache, numpy, multidict, MarkupSafe, joblib, idna, fsspec, frozenlist, clint, charset_normalizer, certifi, attrs, aiohappyeyeballs, yarl, scipy, requests, python-dateutil, jinja2, aiosignal, scikit-learn, pandas, aiohttp, torch-geometric, py-tgb
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.14.1
#     Uninstalling typing_extensions-4.14.1:
#       Successfully uninstalled typing_extensions-4.14.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.3
#     Uninstalling pyparsing-3.2.3:
#       Successfully uninstalled pyparsing-3.2.3
#   Attempting uninstall: psutil
#     Found existing installation: psutil 6.0.0
#     Not uninstalling psutil at /toolkit-cache/0.2.29/python3.11/kernel-libs/lib/python3.11/site-packages, outside environment /root/venv
#     Can't uninstall 'psutil'. No files were found to uninstall.
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.1
#     Uninstalling joblib-1.5.1:
#       Successfully uninstalled joblib-1.5.1
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.7.0
#     Uninstalling fsspec-2025.7.0:
#       Successfully uninstalled fsspec-2025.7.0
#   Attempting uninstall: charset_normalizer
#     Found existing installation: charset-normalizer 3.4.2
#     Uninstalling charset-normalizer-3.4.2:
#       Successfully uninstalled charset-normalizer-3.4.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.7.14
#     Uninstalling certifi-2025.7.14:
#       Successfully uninstalled certifi-2025.7.14
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.1 requires numpy<2.0.0,>=1.23.5, but you have numpy 2.3.2 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.3.2 which is incompatible.
# deepnote-toolkit 0.1.0 requires numpy<2,>=1.21; python_version >= "3.9" and python_version < "4.0", but you have numpy 2.3.2 which is incompatible.
# deepnote-toolkit 0.1.0 requires numpy<2,>=1.23; python_version >= "3.10" and python_version < "4.0", but you have numpy 2.3.2 which is incompatible.
# deepnote-toolkit 0.1.0 requires numpy<2,>=1.24; python_version >= "3.11" and python_version < "4.0", but you have numpy 2.3.2 which is incompatible.
# deepnote-toolkit 0.1.0 requires pandas<2.2,>=1.2.5; python_version < "3.12", but you have pandas 2.3.2 which is incompatible.
# Successfully installed MarkupSafe-3.0.2 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 args-0.1.0 attrs-25.3.0 certifi-2025.8.3 charset_normalizer-3.4.3 clint-0.5.1 frozenlist-1.7.0 fsspec-2025.7.0 idna-3.10 jinja2-3.1.6 joblib-1.5.2 multidict-6.6.4 numpy-2.3.2 pandas-2.3.2 propcache-0.3.2 psutil-7.0.0 py-tgb-2.1.0 pyparsing-3.2.3 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.32.5 scikit-learn-1.7.1 scipy-1.16.1 six-1.17.0 threadpoolctl-3.6.0 torch-geometric-2.6.1 tqdm-4.67.1 typing-extensions-4.15.0 tzdata-2025.2 urllib3-2.5.0 yarl-1.20.1
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
from torch_geometric.data import DataLoader
from torch_geometric.utils import degree
import numpy as np
from tqdm import tqdm
import numpy as np

def PA(A, edge_index, batch_size=100000):
    # The Preferential-Attachment heuristic score.
    # s(u,v) = deg(u) * deg(v)
    degree_col = A.sum(axis=0)
    degree_row = A.sum(axis=1)
    A_ = A.multiply(degree_col).multiply(degree_row).tocsr()

    link_loader = DataLoader(range(edge_index.size(1)), batch_size)
    scores = []

    for ind in link_loader:
        src = edge_index[0, ind].cpu().numpy().astype(np.int64)
        dst = edge_index[1, ind].cpu().numpy().astype(np.int64)

        cur_scores = np.array([A_[s, d] for s, d in zip(src, dst)])
        scores.append(cur_scores)

    scores = np.concatenate(scores, 0)
    return scores, edge_index

# %%
from tgb.linkproppred.dataset_pyg import PyGLinkPropPredDataset
from tgb.linkproppred.evaluate import Evaluator
from tgb.linkproppred.dataset_pyg import PyGLinkPropPredDataset

dataset_name = "tgbl-wiki"

dataset = PyGLinkPropPredDataset(name=dataset_name, root="datasets")
dataset.load_test_ns() #inductive negative samples
dataset.load_val_ns() #inductive negative samples
    
evaluator = Evaluator(name=dataset_name)
# Out:
# raw file found, skipping download
# Dataset directory is  /root/venv/lib/python3.11/site-packages/tgb/datasets/tgbl_wiki
# loading processed file

# %%
# !pip install torch_geometric

# Optional dependencies:
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.8.0+cpu.html
# Out:
# Requirement already satisfied: torch_geometric in /root/venv/lib/python3.11/site-packages (2.6.1)
# Requirement already satisfied: aiohttp in /root/venv/lib/python3.11/site-packages (from torch_geometric) (3.12.15)
# Requirement already satisfied: fsspec in /root/venv/lib/python3.11/site-packages (from torch_geometric) (2025.7.0)
# Requirement already satisfied: jinja2 in /root/venv/lib/python3.11/site-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /root/venv/lib/python3.11/site-packages (from torch_geometric) (2.3.2)
# Requirement already satisfied: psutil>=5.8.0 in /root/venv/lib/python3.11/site-packages (from torch_geometric) (7.0.0)
# Requirement already satisfied: pyparsing in /root/venv/lib/python3.11/site-packages (from torch_geometric) (3.2.3)
# Requirement already satisfied: requests in /root/venv/lib/python3.11/site-packages (from torch_geometric) (2.32.5)
# Requirement already satisfied: tqdm in /root/venv/lib/python3.11/site-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /root/venv/lib/python3.11/site-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /root/venv/lib/python3.11/site-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /root/venv/lib/python3.11/site-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /root/venv/lib/python3.11/site-packages (from aiohttp->torch_geometric) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /root/venv/lib/python3.11/site-packages (from aiohttp->torch_geometric) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /root/venv/lib/python3.11/site-packages (from aiohttp->torch_geometric) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /root/venv/lib/python3.11/site-packages (from aiohttp->torch_geometric) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.11/site-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/venv/lib/python3.11/site-packages (from requests->torch_geometric) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.11/site-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.11/site-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.11/site-packages (from requests->torch_geometric) (2025.8.3)
# Requirement already satisfied: typing-extensions>=4.2 in /root/venv/lib/python3.11/site-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Looking in links: https://data.pyg.org/whl/torch-2.8.0+cpu.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.8.0%2Bcpu/pyg_lib-0.4.0%2Bpt28cpu-cp311-cp311-linux_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.6 MB/s eta 0:00:00
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.8.0%2Bcpu/torch_scatter-2.1.2%2Bpt28cpu-cp311-cp311-linux_x86_64.whl (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.2/647.2 kB 40.1 MB/s eta 0:00:00
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.8.0%2Bcpu/torch_sparse-0.6.18%2Bpt28cpu-cp311-cp311-linux_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.0 MB/s eta 0:00:00
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.8.0%2Bcpu/torch_cluster-1.6.3%2Bpt28cpu-cp311-cp311-linux_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.4/751.4 kB 60.6 MB/s eta 0:00:00
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.8.0%2Bcpu/torch_spline_conv-1.2.2%2Bpt28cpu-cp311-cp311-linux_x86_64.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /root/venv/lib/python3.11/site-packages (from torch_sparse) (1.16.1)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /root/venv/lib/python3.11/site-packages (from scipy->torch_sparse) (2.3.2)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt28cpu torch_cluster-1.6.3+pt28cpu torch_scatter-2.1.2+pt28cpu torch_sparse-0.6.18+pt28cpu torch_spline_conv-1.2.2+pt28cpu
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
from torch_geometric.data import Data
import torch
import numpy as np
import scipy.sparse as ssp
from tqdm import tqdm

# Number of nodes in the temporal graph
num_nodes = dataset.get_TemporalData().num_nodes

# --- Build the training graph ---
# Stack source and destination nodes from the training edges
#edge_index is the adjaceny matrix in format [[src_edges], [dst_edges]]
#Dataset has no node features, so specifying number nodes will create a node feature matrix of ones
#Otherwise, you can specifiy x as node feature matrix, e.g. x = torch.ones((num_nodes,1))
#This is a PyG Data object
data = Data(
    edge_index=torch.stack((dataset.src[dataset.train_mask], 
                            dataset.dst[dataset.train_mask])),
    num_nodes=num_nodes
)

# --- Convert training edges to sparse adjacency matrix ---
# This is efficient for computing pa scores
edge_weight = torch.ones(data.edge_index.size(1), dtype=int)  # all edges weight=1
A = ssp.csr_matrix(
    (edge_weight, (data.edge_index[0], data.edge_index[1])),
    shape=(num_nodes, num_nodes)
)

# Mask to select test edges
mask = dataset.test_mask

# --- Sample negative edges for evaluation ---
# For each positive test edge, generate non-existent edges (negatives)
# It will create a dict of list, each list contains negative edges for each positive edge.
neg_edges = dataset.negative_sampler.query_batch(
    dataset.src[mask],
    dataset.dst[mask],
    dataset.ts[mask], 
    split_mode='test'
)

# Metric used for evaluation (usually "mrr") [for format required by evaluator object]
metric = dataset.eval_metric

# Stack positive test edges for easy indexing
pos_edge = torch.stack((dataset.src[mask], dataset.dst[mask]))

# List to store per-edge performance
perf_list = []

# --- Main loop: compute PA scores and MRR for each test edge ---
for idx in tqdm(range(len(neg_edges))):
    #Recall that pos_edge is 2D tensor [[src_edges], [dst_edges]]
    neg_batch = neg_edges[idx]             # negative edges for this positive edge
    pos_src = pos_edge[0, idx]             # source node of positive edge
    pos_dst = pos_edge[1, idx]             # destination node of positive edge

    # Prepare query edges: first positive, then negatives
    query_src = torch.Tensor([int(pos_src) for _ in range(len(neg_batch) + 1)])
    query_dst = torch.Tensor([int(pos_dst)] + neg_batch)
    edge_index = torch.stack((query_src, query_dst))

    # Compute Preferential Attachment scores for the batch
    # y_pred[0] -> positive edge, y_pred[1:] -> negative edges
    y_pred, _ = PA(A, edge_index) #your own model

    # --- Compute MRR for this edge ---
    input_dict = {
        "y_pred_pos": np.array([y_pred[0]]),    # score for positive edge
        "y_pred_neg": np.array(y_pred[1:]),     # scores for negatives
        "eval_metric": [metric]                 # evaluation metric
    }
    perf_list.append(evaluator.eval(input_dict)[metric])

# --- Aggregate results ---
perf_metrics = float(np.mean(perf_list))  # mean MRR over all test edges
print(f"TGBL-WIKI MRR Test: {perf_metrics}")
# Out:
#   0%|          | 0/23621 [00:00<?, ?it/s]/root/venv/lib/python3.11/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# 100%|██████████| 23621/23621 [06:18<00:00, 62.39it/s]TGBL-COIN MRR Test: 0.46322616934776306

# %% [markdown]
# # Run continuous-time temporal network models on your own dataset
#
# TGB implementations are mainly based on [DyGLib](https://github.com/yule-BUAA/DyGLib), which easily support the addition of new datasets https://github.com/yule-BUAA/DyGLib/blob/master/DG_data/DATASETS_README.md
#
# Concerning the evaluation setting, TGB adopts the inductive negative sampling strategy available on DyGLib.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=44ea447d-a946-4e9f-93c8-1e95904db5b4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
